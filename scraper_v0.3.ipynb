# %% [markdown]
# import packages

# %%
import pandas as pd
from lxml import html, etree
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DavideLonigro\\Box\\Notebooks\\keepa'

# %%
file = 'asin_list.txt'

# %%
data = open(file,'r')
asin_list = data.read().split('\n')

# %%
def search_multi(asin_list):
    opts = Options()
    opts.headless = True
    driver = webdriver.Chrome(executable_path=r'C:/Users/DavideLonigro/Box/Notebooks/_input/chromedriver.exe',options=opts)
    result = list()
    
    for asin in asin_list:
        driver.get("http://www.amazon.fr/dp/"+asin)
        content = driver.page_source
        doc = html.fromstring(content)
        av = driver.find_element_by_css_selector("#availability > span").text
        title = driver.find_element_by_css_selector("#productTitle").text
        result.append([asin,av,title])
        driver.back()
        
    driver.close()
    return result

# %%
out = search_multi(asin_list)

# %%
df = pd.DataFrame(out, columns=['ASIN','STATUS','NAME'])

# %%
df.to_excel('ciarpame.xlsx')

# %%
df
# Out:
#           ASIN                                             STATUS  \
# 0   B07DP8Y6MK                                          En stock.
# 1   B07FSRCPF5            Habituellement expédié sous 1 à 2 mois.
# 2   B079Q2CHPM                                          En stock.
# 3   B07MMSHC4R                                          En stock.
# 4   B07M5BLCYM                                          En stock.
# 5   B07M8J529L                                          En stock.
# 6   B07MMSWP78                                          En stock.
# 7   B07FVGQGHX                                          En stock.
# 8   B079MNCM31                                          En stock.
# 9   B079MQSYHG     Il ne reste plus que 5 exemplaire(s) en stock.
# 10  B079M9W2MP                                          En stock.
# 11  B07FSSYMFD                                          En stock.
# 12  B01J5FH8L4                                          En stock.
# 13  B079Q278T7     Il ne reste plus que 1 exemplaire(s) en stock.
# 14  B01KWX18PK                                          En stock.
# 15  B08297YNFH                                          En stock.
# 16  B07FST5P1W  Il ne reste plus que 14 exemplaire(s) en stock...
# 17  B07FSNCGKW                                          En stock.
# 18  B074KN3GDW                                          En stock.
# 19  B074KQB4B1                                          En stock.
# 20  B07D6YMZ2H    Il ne reste plus que 10 exemplaire(s) en stock.
# 21  B07D6SJCTB                                          En stock.
# 22  B074KQB4B2  Il ne reste plus que 10 exemplaire(s) en stock...
# 23  B01MUGL47A                                          En stock.
#
#                                                  NAME
# 0   Philips EP5335/10 Machine à café Expresso Supe...
# 1   Philips HD6592/81 Machine à café SENSEO Switch...
# 2   Philips Senseo hd6592/60 Switch 2 en 1 Machine...
# 3   Philips EP2220/10 Machine Espresso automatique...
# 4   Philips EP2221/40 Machine Espresso automatique...
# 5   Philips EP3246/70 Machine à Café Automatique E...
# 6   Philips EP2231/40 Machine à Café Automatique E...
# 7   Philips HD6564/81 Machine à café à dosettes SE...
# 8   Philips HD6563/31 Machine à Café à Dosettes SE...
# 9   Philips HD6563/61 Machine à Café à Dosettes SE...
# 10  Philips HD6563/81 Machine à Café à Dosettes SE...
# 11  Philips HD7866/61 SENSEO Quadrante Machine à d...
# 12  Philips HD7866/61 SENSEO Quadrante Machine à d...
# 13  Philips HD6592/00 Senseo Machine à café 2 en 1...
# 14  Senseo Quadrante HD7865/80 Machine à café auto...
# 15  SAECO Xelsis SM7583/00 Machine Espresso super ...
# 16  Philips HD6566/61 Machine à café à dosettes SE...
# 17  Philips HD6592/61 Machine à café SENSEO Switch...
# 18  Philips HD6554/91 Machine à Café à Dosettes Se...
# 19  Philips HD6554/11 Machine à Café à Dosettes Se...
# 20                   Senseo Original noire + 2 tasses
# 21                   Senseo Original blanc + 2 tasses
# 22  Philips HD6554/61 Machine à Café à Dosettes Se...
# 23  Philips EP3550/00 Séries 3100 Machine Espresso...
